# %%
import sys
from pathlib import Path

CURRENT = Path.cwd().resolve()
PROJECT_ROOT = CURRENT
if not (PROJECT_ROOT / "SEConformer").exists():
    for parent in [CURRENT, *CURRENT.parents]:
        if (parent / "SEConformer").exists():
            PROJECT_ROOT = parent
            break

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import torch
print("Projeto:", PROJECT_ROOT)
print("Torch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("GPU:", torch.cuda.is_available())
# Out:
# Projeto: C:\Users\franc\OneDrive\Desktop\Breast Cancer
# Torch: 2.6.0+cu124
# CUDA: 12.4
# GPU: True

# %%
from SEConformer import DEVICE, build_breakhis_dataframe, make_run_dirs, train_breakhis_holdout

BREAKHIS_BASE_PATH = PROJECT_ROOT / "BrestCancer Datasets" / "BreaKHis" / "BreaKHis_v1" / "BreaKHis_v1" / "histology_slides" / "breast"

print("Device:", DEVICE)
print("Dataset:", BREAKHIS_BASE_PATH)
# Out:
# Device: cuda
# Dataset: C:\Users\franc\OneDrive\Desktop\Breast Cancer\BrestCancer Datasets\BreaKHis\BreaKHis_v1\BreaKHis_v1\histology_slides\breast

# %%
df = build_breakhis_dataframe(
    base_path=str(BREAKHIS_BASE_PATH),
    mode="binary",
)
print("Total imagens:", len(df))
df.head()
# Out:
# Total imagens: 7909
#                                           image_path  label class_name
# 0  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0     benign
# 1  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0     benign
# 2  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0     benign
# 3  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0     benign
# 4  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0     benign

# %%
run_dirs = make_run_dirs(run_prefix="seconformer_breakhis_holdout")
model, run_dirs, metrics = train_breakhis_holdout(
    base_path=str(BREAKHIS_BASE_PATH),
    mode="binary",
    val_fraction=0.2,
    epochs=20,
    batch_size=16,
    run_dirs=run_dirs,
    img_size=224,
    balance=True,
)

print("Run:", run_dirs["out_dir"])
metrics
# Out:
# 100%|██████████| 396/396 [05:58<00:00,  1.10it/s]
# Epoch 0 Loss: 0.3968
# RESULTADOS:
# accuracy: 0.8197
# precision: 0.9598
# recall: 0.7637
# specificity: 0.9345
# f1_score: 0.8506
# auc: 0.9443
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_0_metrics.json
# 100%|██████████| 396/396 [05:59<00:00,  1.10it/s]
# Epoch 1 Loss: 0.3211
# RESULTADOS:
# accuracy: 0.8767
# precision: 0.9238
# recall: 0.8898
# specificity: 0.8497
# f1_score: 0.9065
# auc: 0.9469
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_1_metrics.json
# 100%|██████████| 396/396 [06:10<00:00,  1.07it/s]
# Epoch 2 Loss: 0.2928
# RESULTADOS:
# accuracy: 0.8691
# precision: 0.9831
# recall: 0.8192
# specificity: 0.9711
# f1_score: 0.8937
# auc: 0.9670
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_2_metrics.json
# 100%|██████████| 396/396 [06:06<00:00,  1.08it/s]
# Epoch 3 Loss: 0.2673
# RESULTADOS:
# accuracy: 0.9013
# precision: 0.9789
# recall: 0.8719
# specificity: 0.9615
# f1_score: 0.9223
# auc: 0.9708
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_3_metrics.json
# 100%|██████████| 396/396 [06:04<00:00,  1.09it/s]
# Epoch 4 Loss: 0.2417
# RESULTADOS:
# accuracy: 0.8558
# precision: 0.9883
# recall: 0.7947
# specificity: 0.9807
# f1_score: 0.8810
# auc: 0.9711
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_4_metrics.json
# 100%|██████████| 396/396 [06:19<00:00,  1.04it/s]
# Epoch 5 Loss: 0.2289
# RESULTADOS:
# accuracy: 0.8950
# precision: 0.9817
# recall: 0.8597
# specificity: 0.9672
# f1_score: 0.9167
# auc: 0.9787
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_5_metrics.json
# 100%|██████████| 396/396 [05:58<00:00,  1.11it/s]
# Epoch 6 Loss: 0.2290
# RESULTADOS:
# accuracy: 0.9051
# precision: 0.9597
# recall: 0.8964
# specificity: 0.9229
# f1_score: 0.9270
# auc: 0.9679
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_6_metrics.json
# 100%|██████████| 396/396 [05:57<00:00,  1.11it/s]
# Epoch 7 Loss: 0.2062
# RESULTADOS:
# accuracy: 0.8710
# precision: 0.9920
# recall: 0.8145
# specificity: 0.9865
# f1_score: 0.8945
# auc: 0.9806
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_7_metrics.json
# 100%|██████████| 396/396 [05:59<00:00,  1.10it/s]
# Epoch 8 Loss: 0.1916
# RESULTADOS:
# accuracy: 0.8552
# precision: 0.9988
# recall: 0.7853
# specificity: 0.9981
# f1_score: 0.8793
# auc: 0.9840
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_8_metrics.json
# 100%|██████████| 396/396 [05:53<00:00,  1.12it/s]
# Epoch 9 Loss: 0.1831
# RESULTADOS:
# accuracy: 0.9121
# precision: 0.9724
# recall: 0.8945
# specificity: 0.9480
# f1_score: 0.9318
# auc: 0.9784
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_9_metrics.json
# 100%|██████████| 396/396 [05:53<00:00,  1.12it/s]
# Epoch 10 Loss: 0.1812
# RESULTADOS:
# accuracy: 0.9273
# precision: 0.9711
# recall: 0.9190
# specificity: 0.9441
# f1_score: 0.9444
# auc: 0.9837
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_10_metrics.json
# 100%|██████████| 396/396 [05:48<00:00,  1.14it/s]
# Epoch 11 Loss: 0.1614
# RESULTADOS:
# accuracy: 0.9292
# precision: 0.9769
# recall: 0.9162
# specificity: 0.9557
# f1_score: 0.9456
# auc: 0.9849
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_11_metrics.json
# 100%|██████████| 396/396 [05:49<00:00,  1.13it/s]
# Epoch 12 Loss: 0.1682
# RESULTADOS:
# accuracy: 0.8982
# precision: 0.9902
# recall: 0.8569
# specificity: 0.9827
# f1_score: 0.9187
# auc: 0.9847
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_12_metrics.json
# 100%|██████████| 396/396 [05:48<00:00,  1.14it/s]
# Epoch 13 Loss: 0.1708
# RESULTADOS:
# accuracy: 0.9039
# precision: 0.9882
# recall: 0.8672
# specificity: 0.9788
# f1_score: 0.9238
# auc: 0.9841
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_13_metrics.json
# 100%|██████████| 396/396 [05:56<00:00,  1.11it/s]
# Epoch 14 Loss: 0.1500
# RESULTADOS:
# accuracy: 0.8767
# precision: 0.9932
# recall: 0.8220
# specificity: 0.9884
# f1_score: 0.8995
# auc: 0.9809
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_14_metrics.json
# 100%|██████████| 396/396 [06:22<00:00,  1.04it/s]
# Epoch 15 Loss: 0.1552
# RESULTADOS:
# accuracy: 0.9380
# precision: 0.9763
# recall: 0.9303
# specificity: 0.9538
# f1_score: 0.9527
# auc: 0.9848
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_15_metrics.json
# 100%|██████████| 396/396 [06:31<00:00,  1.01it/s]
# Epoch 16 Loss: 0.1429
# RESULTADOS:
# accuracy: 0.9386
# precision: 0.9889
# recall: 0.9190
# specificity: 0.9788
# f1_score: 0.9527
# auc: 0.9886
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_16_metrics.json
# 100%|██████████| 396/396 [06:17<00:00,  1.05it/s]
# Epoch 17 Loss: 0.1546
# RESULTADOS:
# accuracy: 0.9330
# precision: 0.9908
# recall: 0.9087
# specificity: 0.9827
# f1_score: 0.9479
# auc: 0.9899
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_17_metrics.json
# 100%|██████████| 396/396 [06:11<00:00,  1.07it/s]
# Epoch 18 Loss: 0.1299
# RESULTADOS:
# accuracy: 0.9405
# precision: 0.9754
# recall: 0.9350
# specificity: 0.9518
# f1_score: 0.9548
# auc: 0.9875
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_18_metrics.json
# 100%|██████████| 396/396 [06:12<00:00,  1.06it/s]
# Epoch 19 Loss: 0.1353
# RESULTADOS:
# accuracy: 0.9279
# precision: 0.9857
# recall: 0.9058
# specificity: 0.9730
# f1_score: 0.9441
# auc: 0.9869
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\epoch_19_metrics.json
# RESULTADOS:
# accuracy: 0.9279
# precision: 0.9857
# recall: 0.9058
# specificity: 0.9730
# f1_score: 0.9441
# auc: 0.9869
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\plots\final_confusion_matrix.png
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\plots\final_roc.png
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\plots\final_precision_recall.png
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\plots\final_prob_distribution.png
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\final_metrics.json
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\history.csv
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\models\seconformer_breakhis.pt
# Salvo: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902\final_metrics.json
# Run: C:\Users\franc\OneDrive\Desktop\Breast Cancer\SEConformer\runs\seconformer_breakhis_holdout_20260519-100902
# {'accuracy': 0.9278937381404174,
#  'precision': 0.985655737704918,
#  'recall': 0.9058380414312618,
#  'specificity': 0.9730250481695568,
#  'f1_score': 0.9440628066732091,
#  'auc': 0.9868663117903835}
