# %%
import torch
print("Torch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("GPU:", torch.cuda.is_available())

# %%
from HISTODX_TORCH import (
    run_histodx_torch,
    make_run_dirs,
    SEED,
    IMG_SIZE,
    BATCH_SIZE,
    EPOCHS,
    LEARNING_RATE,
)

# %%
DATASET_PATH = r"C:\Users\franc\OneDrive\Desktop\Breast Cancer\BrestCancer Datasets\BreaKHis"
run_dirs = make_run_dirs()
print("Run:", run_dirs["out_dir"])
# Out:
# Run: results/HistoDX_Torch\histodx_torch_20260406-224304

# %%
results = run_histodx_torch(
    dataset_path=DATASET_PATH,
    img_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    learning_rate=LEARNING_RATE,
    run_dirs=run_dirs,
    seed=SEED,
)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth" to C:\Users\franc/.cache\torch\hub\checkpoints\efficientnet_v2_s-dd5fe13b.pth
# 100%|██████████| 82.7M/82.7M [00:24<00:00, 3.49MB/s]
# 100%|██████████| 173/173 [02:07<00:00,  1.35it/s]
# Epoch 0 Loss: 0.3348 | Val Acc: 0.9637
#  56%|█████▌    | 97/173 [01:07<00:53,  1.42it/s]
