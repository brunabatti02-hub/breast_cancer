# %%
import sys
from pathlib import Path

CURRENT = Path.cwd().resolve()
PROJECT_ROOT = CURRENT
if not (PROJECT_ROOT / "HFTNET").exists():
    for parent in [CURRENT, *CURRENT.parents]:
        if (parent / "HFTNET").exists():
            PROJECT_ROOT = parent
            break

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import torch
print("Projeto:", PROJECT_ROOT)
print("Torch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("GPU:", torch.cuda.is_available())
# Out:
# Projeto: C:\Users\franc\OneDrive\Desktop\Breast Cancer
# Torch: 2.6.0+cu124
# CUDA: 12.4
# GPU: True

# %%
from HFTNET import make_run_dirs, parse_breakhis_dataset, run_breakhis_baseline_holdout

BREAKHIS_BASE_PATH = PROJECT_ROOT / "BrestCancer Datasets" / "BreaKHis" / "BreaKHis_v1" / "BreaKHis_v1" / "histology_slides" / "breast"

# %%
df = parse_breakhis_dataset(str(BREAKHIS_BASE_PATH), mode="multiclass")
print("Total imagens:", len(df))
df.head()
# Out:
# Total imagens: 7909
#                                           image_path  label class_name
# 0  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0   adenosis
# 1  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0   adenosis
# 2  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0   adenosis
# 3  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0   adenosis
# 4  C:\Users\franc\OneDrive\Desktop\Breast Cancer\...      0   adenosis

# %%
run_dirs = make_run_dirs(run_prefix="hftnet_breakhis_holdout")
model, history, best_outputs, run_dirs = run_breakhis_baseline_holdout(
    base_path=str(BREAKHIS_BASE_PATH),
    mode="multiclass",
    val_fraction=0.2,
    epochs=1,
    batch_size=8,
    run_dirs=run_dirs,
    img_size=224,
    balance=True,
)

print("Run:", run_dirs["out_dir"])
# Out:
# c:\Users\franc\venvs\bc311\Lib\site-packages\timm\models\_factory.py:138: UserWarning: Mapping deprecated model name xception to current legacy_xception.
#   model = create_fn(
# Unexpected keys (norm.bias, norm.weight) found while loading pretrained weights. This may be expected if model is being adapted.
# Unexpected keys (norm.bias, norm.weight) found while loading pretrained weights. This may be expected if model is being adapted.
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 2
#       1 run_dirs = make_run_dirs(run_prefix="hftnet_breakhis_holdout")
# ----> 2 model, history, best_outputs, run_dirs = run_breakhis_baseline_holdout(
#       3     base_path=str(BREAKHIS_BASE_PATH),
#       4     mode="multiclass",
#       5     val_fraction=0.2,
#       6     epochs=1,
#       7     batch_size=8,
#       8     run_dirs=run_dirs,
#       9     img_size=224,
# ...
