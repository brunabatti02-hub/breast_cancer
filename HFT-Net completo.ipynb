# %%
import torch
print("Torch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("GPU:", torch.cuda.is_available())

# %%
from HFTNET import (
    BASE_PATH,
    CSV_PATH,
    EPOCHS,
    make_run_dirs,
    parse_breakhis_dataset,
    build_folds_csv,
    run_training,
)

# %%
run_dirs = make_run_dirs()
print("Run:", run_dirs["out_dir"])

# %%
df = parse_breakhis_dataset(BASE_PATH)
print("Total imagens encontradas:", len(df))

df = build_folds_csv(df, CSV_PATH, n_splits=5, seed=42)

# %%
model, history, best_outputs, run_dirs = run_training(
    CSV_PATH,
    fold=0,
    epochs=EPOCHS,
    run_dirs=run_dirs,
)
